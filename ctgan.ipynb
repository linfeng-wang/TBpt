# %%
from ctgan import CTGAN
from ctgan import load_demo
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ctgan import CTGAN
#       2 from ctgan import load_demo
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/ctgan/__init__.py:10
#       7 __version__ = '0.10.1'
#       9 from ctgan.demo import load_demo
# ---> 10 from ctgan.synthesizers.ctgan import CTGAN
#      11 from ctgan.synthesizers.tvae import TVAE
#      13 __all__ = (
#      14     'CTGAN',
#      15     'TVAE',
#      16     'load_demo'
#      17 )
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/ctgan/synthesizers/__init__.py:3
#       1 """Synthesizers module."""
# ----> 3 from ctgan.synthesizers.ctgan import CTGAN
#       4 from ctgan.synthesizers.tvae import TVAE
#       6 __all__ = (
#       7     'CTGAN',
#       8     'TVAE'
#       9 )
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/ctgan/synthesizers/ctgan.py:13
#      10 from tqdm import tqdm
#      12 from ctgan.data_sampler import DataSampler
# ---> 13 from ctgan.data_transformer import DataTransformer
#      14 from ctgan.synthesizers.base import BaseSynthesizer, random_state
#      17 class Discriminator(Module):
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/ctgan/data_transformer.py:8
#       6 import pandas as pd
#       7 from joblib import Parallel, delayed
# ----> 8 from rdt.transformers import ClusterBasedNormalizer, OneHotEncoder
#      10 SpanInfo = namedtuple('SpanInfo', ['dim', 'activation_fn'])
#      11 ColumnTransformInfo = namedtuple(
#      12     'ColumnTransformInfo', [
#      13         'column_name', 'column_type', 'transform', 'output_info', 'output_dimensions'
#      14     ]
#      15 )
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/rdt/__init__.py:19
#      16 import numpy as np
#      17 import pandas as pd
# ---> 19 from rdt import transformers
#      20 from rdt.hyper_transformer import HyperTransformer
#      22 __all__ = ['HyperTransformer', 'transformers']
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/rdt/transformers/__init__.py:11
#       9 from rdt.transformers.base import BaseMultiColumnTransformer, BaseTransformer
#      10 from rdt.transformers.boolean import BinaryEncoder
# ---> 11 from rdt.transformers.categorical import (
#      12     CustomLabelEncoder,
#      13     FrequencyEncoder,
#      14     LabelEncoder,
#      15     OneHotEncoder,
#      16     OrderedLabelEncoder,
#      17     OrderedUniformEncoder,
#      18     UniformEncoder,
#      19 )
#      20 from rdt.transformers.datetime import (
#      21     OptimizedTimestampEncoder,
#      22     UnixTimestampEncoder,
#      23 )
#      24 from rdt.transformers.null import NullTransformer
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/rdt/transformers/categorical.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from scipy.stats import norm
#      10 from rdt.errors import TransformerInputError
#      11 from rdt.transformers.base import BaseTransformer
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/stats/__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/stats/_stats_py.py:49
#      47 import scipy.special as special
#      48 from scipy import linalg
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#      51 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      52                                    siegelslopes)
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/stats/distributions.py:11
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
#      10 from . import _continuous_distns
# ---> 11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#      14 from ._levy_stable import levy_stable
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:10
#       8 from scipy.special import entr, logsumexp, betaln, gammaln as gamln, zeta
#       9 from scipy._lib._util import _lazywhere, rng_integers
# ---> 10 from scipy.interpolate import interp1d
#      12 from numpy import floor, ceil, log, exp, sqrt, log1p, expm1, tanh, cosh, sinh
#      14 import numpy as np
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/interpolate/__init__.py:167
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     165 (should not be used in new code).
#     166 """
# --> 167 from ._interpolate import *
#     168 from ._fitpack_py import *
#     170 # New interface to fitpack library:
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:14
#      11 from scipy._lib._util import copy_if_needed
#      12 from scipy.special import comb
# ---> 14 from . import _fitpack_py
#      15 from . import dfitpack
#      16 from ._polyint import _Interpolator1D
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/interpolate/_fitpack_py.py:8
#       5 import numpy as np
#       7 # These are in the API for fitpack even if not used in fitpack.py itself.
# ----> 8 from ._fitpack_impl import bisplrep, bisplev, dblint  # noqa: F401
#       9 from . import _fitpack_impl as _impl
#      10 from ._bsplines import BSpline
#
# File /mnt/storageG1/lwang/miniconda3/envs/ctgan/lib/python3.9/site-packages/scipy/interpolate/_fitpack_impl.py:103
#      52 _iermess = {
#      53     0: ["The spline has a residual sum of squares fp such that "
#      54         "abs(fp-s)/s<=0.001", None],
#    (...)
#      68     'unknown': ["An error occurred", TypeError]
#      69 }
#      71 _iermess2 = {
#      72     0: ["The spline has a residual sum of squares fp such that "
#      73         "abs(fp-s)/s<=0.001", None],
#    (...)
#      99     'unknown': ["An error occurred", TypeError]
#     100 }
#     102 _parcur_cache = {'t': array([], float), 'wrk': array([], float),
# --> 103                  'iwrk': array([], dfitpack_int), 'u': array([], float),
#     104                  'ub': 0, 'ue': 1}
#     107 def splprep(x, w=None, u=None, ub=None, ue=None, k=3, task=0, s=None, t=None,
#     108             full_output=0, nest=None, per=0, quiet=1):
#     109     # see the docstring of `_fitpack_py/splprep`
#     110     if task <= 0:
#
# TypeError:

# %%
real_data = load_demo()

# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan = CTGAN(epochs=10)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(1000)
